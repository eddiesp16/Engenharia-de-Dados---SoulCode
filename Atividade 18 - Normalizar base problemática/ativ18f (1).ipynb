# %%
# !pip install pandas
# !pip install pymongo[srv]
# !pip install gcsfs
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Collecting pymongo[srv]
#   Downloading pymongo-4.1.1-cp39-cp39-win_amd64.whl (365 kB)
# Collecting dnspython<3.0.0,>=1.16.0
#   Using cached dnspython-2.2.1-py3-none-any.whl (269 kB)
# Installing collected packages: pymongo, dnspython
# Successfully installed dnspython-2.2.1 pymongo-4.1.1
# Collecting gcsfs
#   Downloading gcsfs-2022.3.0-py2.py3-none-any.whl (25 kB)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-2.3.0-py2.py3-none-any.whl (107 kB)
# Collecting fsspec==2022.3.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from gcsfs) (2.26.0)
# Collecting google-auth>=1.2
#   Downloading google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-0.5.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: decorator>4.1.2 in c:\programdata\anaconda3\lib\site-packages (from gcsfs) (5.1.0)
# Collecting aiohttp<4
#   Downloading aiohttp-3.8.1-cp39-cp39-win_amd64.whl (554 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp39-cp39-win_amd64.whl (33 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4->gcsfs) (21.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\programdata\anaconda3\lib\site-packages (from aiohttp<4->gcsfs) (2.0.4)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp39-cp39-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp39-cp39-win_amd64.whl (122 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth>=1.2->gcsfs) (1.16.0)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: idna>=2.0 in c:\programdata\anaconda3\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4->gcsfs) (3.2)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->gcsfs) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->gcsfs) (1.26.7)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Downloading google_api_core-2.7.3-py3-none-any.whl (114 kB)
# Collecting protobuf
#   Downloading protobuf-3.20.1-cp39-cp39-win_amd64.whl (904 kB)
# Collecting google-resumable-media>=2.3.2
#   Downloading google_resumable_media-2.3.2-py2.py3-none-any.whl (76 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.3.0-py2.py3-none-any.whl (29 kB)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.56.0-py2.py3-none-any.whl (241 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.3.0-cp39-cp39-win_amd64.whl (27 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, googleapis-common-protos, google-auth, oauthlib, multidict, google-crc32c, google-api-core, frozenlist, yarl, requests-oauthlib, google-resumable-media, google-cloud-core, async-timeout, aiosignal, google-cloud-storage, google-auth-oauthlib, fsspec, aiohttp, gcsfs
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.10.1
#     Uninstalling fsspec-2021.10.1:
# ERROR: Could not install packages due to an OSError: [WinError 5] Acesso negado: 'c:\\programdata\\anaconda3\\lib\\site-packages\\fsspec-2021.10.1.dist-info\\direct_url.json'
# Consider using the `--user` option or check the permissions.

# %%
import pandas as pd
df = pd.read_csv('ocorrencias.csv', sep=';')
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  52242               52242                INCIDENTE
# 1                  45331               45331                 ACIDENTE
# 2                  45333               45333                 ACIDENTE
# 3                  45401               45401                 ACIDENTE
# 4                  45407               45407                 ACIDENTE
# ...                  ...                 ...                      ...
# 5162               80458               80458                 ACIDENTE
# 5163               80452               80452                 ACIDENTE
# 5164               80457               80457          INCIDENTE GRAVE
# 5165               80460               80460                INCIDENTE
# 5166               80467               80467                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                    NaN                  NaN      PORTO ALEGRE            RS
# 1         -23.4355555556       -46.4730555556         GUARULHOS            SP
# 2                    ***                  ***            VIAMÃO            RS
# 3                    ***                  ***     SÃO SEBASTIÃO            SP
# 4                    ***                  ***          SÃO SEPÉ            RS
# ...                  ...                  ...               ...           ...
# 5162          -17.999194           -51.642861             JATAÍ            GO
# 5163          -22.585556           -50.753889           MARACAÍ            SP
# 5164          -29.695833           -51.081667     NOVO HAMBURGO            RS
# 5165          -25.403333           -49.233611          CURITIBA            PR
# 5166             -9.3675      -40.56361111111         PETROLINA            PE
#
#       ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     ...     05/01/2012        20:27:00                            ***
# 1     ...     06/01/2012        13:44:00                            SIM
# 2     ...     06/01/2012        13:00:00                            NaN
# 3     ...     06/01/2012        17:00:00                            ***
# 4     ...     06/01/2012        16:30:00                            SIM
# ...   ...            ...             ...                            ...
# 5162  ...     30/12/2021        20:30:00                            SIM
# 5163  ...     31/12/2021        09:30:00                            SIM
# 5164  ...     31/12/2021        11:59:00                            SIM
# 5165  ...     31/12/2021        15:12:00                            SIM
# 5166  ...     31/12/2021        20:30:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 0             FINALIZADA                         ***
# 1             FINALIZADA           A-582/CENIPA/2014
# 2             FINALIZADA           A-070/CENIPA/2013
# 3                    NaN                         NaN
# 4             FINALIZADA           A-071/CENIPA/2013
# ...                  ...                         ...
# 5162               ATIVA                   A DEFINIR
# 5163               ATIVA                   A DEFINIR
# 5164          FINALIZADA                         ***
# 5165          FINALIZADA                         ***
# 5166          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                               NÃO                       NaN
# 1                               SIM                2016-09-01
# 2                               SIM                2013-11-27
# 3                               NÃO                       NaN
# 4                               SIM                2013-11-27
# ...                             ...                       ...
# 5162                            NÃO                       NaN
# 5163                            NÃO                       NaN
# 5164                            NÃO                       NaN
# 5165                            NÃO                       NaN
# 5166                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                      0                          1                     NÃO
# 1                      3                          1                     NÃO
# 2                      0                          1                     NÃO
# 3                      0                          1                     NÃO
# 4                      0                          1                     NÃO
# ...                  ...                        ...                     ...
# 5162                   0                          1                     NÃO
# 5163                   0                          1                     NÃO
# 5164                   0                          1                     NÃO
# 5165                   0                          1                     NÃO
# 5166                   0                          1                     NÃO
#
# [5167 rows x 22 columns]

# %%
import pymongo
import json
from pymongo import MongoClient

# %%
import pymongo
conn_str = "mongodb+srv://dbmongo:91150364@cluster0.aa2oq.mongodb.net/ativ18.ativ18"
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
try:
    print(client.server_info())
    print("Able to connect to the server.")
except Exception:
    print("Unable to connect to the server.")
# Out:
# {'version': '5.0.8', 'gitVersion': 'c87e1c23421bf79614baf500fda6622bd90f674e', 'modules': ['enterprise'], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [5, 0, 8, 0], 'openssl': {'running': 'OpenSSL 1.0.1e-fips 11 Feb 2013', 'compiled': 'OpenSSL 1.0.1e-fips 11 Feb 2013'}, 'buildEnvironment': {'distmod': 'rhel70', 'distarch': 'x86_64', 'cc': '/opt/mongodbtoolchain/v3/bin/gcc: gcc (GCC) 8.5.0', 'ccflags': '-Werror -include mongo/platform/basic.h -fasynchronous-unwind-tables -ggdb -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -fno-omit-frame-pointer -fno-strict-aliasing -O2 -march=sandybridge -mtune=generic -mprefer-vector-width=128 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -Wa,--nocompress-debug-sections -fno-builtin-memcmp', 'cxx': '/opt/mongodbtoolchain/v3/bin/g++: g++ (GCC) 8.5.0', 'cxxflags': '-Woverloaded-virtual -Wno-maybe-uninitialized -fsized-deallocation -std=c++17', 'linkflags': '-Wl,--fatal-warnings -pthread -Wl,-z,now -fuse-ld=gold -fstack-protector-strong -Wl,--no-threads -Wl,--build-id -Wl,--hash-style=gnu -Wl,-z,noexecstack -Wl,--warn-execstack -Wl,-z,relro -Wl,--compress-debug-sections=none -Wl,-rpath,/usr/lib64/perl5/CORE -Wl,-z,origin -Wl,--enable-new-dtags', 'target_arch': 'x86_64', 'target_os': 'linux', 'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE_STATIC NDEBUG _XOPEN_SOURCE 700 _GNU_SOURCE _FORTIFY_SOURCE 2 BOOST_THREAD_VERSION 5 BOOST_THREAD_USES_DATETIME BOOST_SYSTEM_NO_DEPRECATED BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR ABSL_FORCE_ALIGNED_ACCESS'}, 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'ephemeralForTest', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1652154063, 3), 'signature': {'hash': b'\xab\xd0":*E\x1b\xfb\x17>\x0e\x9c\x87\x8b\x99hM\x1b\x98\x1d', 'keyId': 7051593322229399553}}, 'operationTime': Timestamp(1652154063, 3)}
# Able to connect to the server.

# %%
df.head()
df.tail()
df.shape
data = df.to_dict(orient = "records")
data
db = client["At18"]
print(db)
db.ocorrencias.insert_many(data)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.aa2oq.mongodb.net:27017', 'cluster0-shard-00-02.aa2oq.mongodb.net:27017', 'cluster0-shard-00-01.aa2oq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-dy2py4-shard-0', tls=True, serverselectiontimeoutms=5000), 'At18')

# %%
conn_str = "mongodb+srv://user:password@cluster0.aa2oq.mongodb.net/ativ18.ativ18"
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
try:
    print(client.server_info())
    print("Able to connect to the server.")
except Exception:
    print("Unable to connect to the server.")
# Out:
# {'version': '5.0.8', 'gitVersion': 'c87e1c23421bf79614baf500fda6622bd90f674e', 'modules': ['enterprise'], 'allocator': 'tcmalloc', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [5, 0, 8, 0], 'openssl': {'running': 'OpenSSL 1.0.1e-fips 11 Feb 2013', 'compiled': 'OpenSSL 1.0.1e-fips 11 Feb 2013'}, 'buildEnvironment': {'distmod': 'rhel70', 'distarch': 'x86_64', 'cc': '/opt/mongodbtoolchain/v3/bin/gcc: gcc (GCC) 8.5.0', 'ccflags': '-Werror -include mongo/platform/basic.h -fasynchronous-unwind-tables -ggdb -Wall -Wsign-compare -Wno-unknown-pragmas -Winvalid-pch -fno-omit-frame-pointer -fno-strict-aliasing -O2 -march=sandybridge -mtune=generic -mprefer-vector-width=128 -Wno-unused-local-typedefs -Wno-unused-function -Wno-deprecated-declarations -Wno-unused-const-variable -Wno-unused-but-set-variable -Wno-missing-braces -fstack-protector-strong -Wa,--nocompress-debug-sections -fno-builtin-memcmp', 'cxx': '/opt/mongodbtoolchain/v3/bin/g++: g++ (GCC) 8.5.0', 'cxxflags': '-Woverloaded-virtual -Wno-maybe-uninitialized -fsized-deallocation -std=c++17', 'linkflags': '-Wl,--fatal-warnings -pthread -Wl,-z,now -fuse-ld=gold -fstack-protector-strong -Wl,--no-threads -Wl,--build-id -Wl,--hash-style=gnu -Wl,-z,noexecstack -Wl,--warn-execstack -Wl,-z,relro -Wl,--compress-debug-sections=none -Wl,-rpath,/usr/lib64/perl5/CORE -Wl,-z,origin -Wl,--enable-new-dtags', 'target_arch': 'x86_64', 'target_os': 'linux', 'cppdefines': 'SAFEINT_USE_INTRINSICS 0 PCRE_STATIC NDEBUG _XOPEN_SOURCE 700 _GNU_SOURCE _FORTIFY_SOURCE 2 BOOST_THREAD_VERSION 5 BOOST_THREAD_USES_DATETIME BOOST_SYSTEM_NO_DEPRECATED BOOST_MATH_NO_LONG_DOUBLE_MATH_FUNCTIONS BOOST_ENABLE_ASSERT_DEBUG_HANDLER BOOST_LOG_NO_SHORTHAND_NAMES BOOST_LOG_USE_NATIVE_SYSLOG BOOST_LOG_WITHOUT_THREAD_ATTR ABSL_FORCE_ALIGNED_ACCESS'}, 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'ephemeralForTest', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1652154429, 8), 'signature': {'hash': b'\x89\xe5/\xe6-\xf4K\xb0pVX\r9\x18\xaa\xa9\x97\x8d\x83\x94', 'keyId': 7051593322229399553}}, 'operationTime': Timestamp(1652154429, 8)}
# Able to connect to the server.

# %%
db = client["At18"]
print(db)
mycollection = db["ocorrencias"]
print(mycollection)
one_record = mycollection.find_one()
all_records = mycollection.find()
for row in all_records:
    print(row)
all_records = mycollection.find()
print(all_records)
list_cursor = list(all_records)
# Out:
# Database(MongoClient(host=['cluster0-shard-00-00.aa2oq.mongodb.net:27017', 'cluster0-shard-00-02.aa2oq.mongodb.net:27017', 'cluster0-shard-00-01.aa2oq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas
 'ocorrencia_classificacao': 'ACIDENTE', 'ocorrencia_latitude': '\\t-32.06444444\\t', 'ocorrencia_longitude': '\\t-52.78083333\\t', 'ocorrencia_cidade': 'ARROIO GRANDE', 'ocorrencia_uf': 'RS', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': '****', 'ocorrencia_dia': '08/02/2018', 'ocorrencia_hora': '15:30:00', 'investigacao_aeronave_liberada': 'SIM', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': 'A-022/CENIPA/2018', 'divulgacao_relatorio_publicado': 'SIM', 'divulgacao_dia_publicacao': '2020-03-11', 'total_recomendacoes': 2, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}
# {'_id': ObjectId('6279df14c1ef959aa00f3a8c'), 'codigo_ocorrencia': 77705, 'codigo_ocorrencia1': 77705, 'codigo_ocorrencia2': 77705, 'codigo_ocorrencia3': 77705, 'codigo_ocorrencia4': 77705, 'ocorrencia_classificacao': 'INCIDENTE', 'ocorrencia_latitude': '-208.161.111.11', 'ocorrencia_longitude': '-494.047.222.22', 'ocorrencia_cidade': 'SÃO JOSÉ DO RIO PRETO', 'ocorrencia_uf': 'SP', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': 'SBSR', 'ocorrencia_dia': '08/02/2018', 'ocorrencia_hora': '18:00:00', 'investigacao_aeronave_liberada': 'SIM', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': '***', 'divulgacao_relatorio_publicado': 'NÃO', 'divulgacao_dia_publicacao': nan, 'total_recomendacoes': 0, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}
# {'_id': ObjectId('6279df14c1ef959aa00f3a8d'), 'codigo_ocorrencia': 77667, 'codigo_ocorrencia1': 77667, 'codigo_ocorrencia2': 77667, 'codigo_ocorrencia3': 77667, 'codigo_ocorrencia4': 77667, 'ocorrencia_classificacao': 'ACIDENTE', 'ocorrencia_latitude': '-12.6', 'ocorrencia_longitude': '-513.833.333.33', 'ocorrencia_cidade': 'RIBEIRÃO CASCALHEIRA', 'ocorrencia_uf': 'MT', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': '****', 'ocorrencia_dia': '09/02/2018', 'ocorrencia_hora': '14:00:00', 'investigacao_aeronave_liberada': 'SIM', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': 'A-023/CENIPA/2018', 'divulgacao_relatorio_publicado': 'SIM', 'divulgacao_dia_publicacao': '2020-05-29', 'total_recomendacoes': 1, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}
# {'_id': ObjectId('6279df14c1ef959aa00f3a8e'), 'codigo_ocorrencia': 77707, 'codigo_ocorrencia1': 77707, 'codigo_ocorrencia2': 77707, 'codigo_ocorrencia3': 77707, 'codigo_ocorrencia4': 77707, 'ocorrencia_classificacao': 'INCIDENTE', 'ocorrencia_latitude': '-235.069.444.44', 'ocorrencia_longitude': '-466.341.666.66', 'ocorrencia_cidade': 'SÃO PAULO', 'ocorrencia_uf': 'SP', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': 'SBMT', 'ocorrencia_dia': '09/02/2018', 'ocorrencia_hora': '19:07:00', 'investigacao_aeronave_liberada': 'SIM', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': '***', 'divulgacao_relatorio_publicado': 'NÃO', 'divulgacao_dia_publicacao': nan, 'total_recomendacoes': 0, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}
# {'_id': ObjectId('6279df14c1ef959aa00f3a8f'), 'codigo_ocorrencia': 77690, 'codigo_ocorrencia1': 77690, 'codigo_ocorrencia2': 77690, 'codigo_ocorrencia3': 77690, 'codigo_ocorrencia4': 77690, 'ocorrencia_classificacao': 'ACIDENTE', 'ocorrencia_latitude': '-10.017222222', 'ocorrencia_longitude': '-67.7125', 'ocorrencia_cidade': 'RIO BRANCO', 'ocorrencia_uf': 'AC', 'ocorrencia_pais': 'BRASIL', 'ocorrencia_aerodromo': '****', 'ocorrencia_dia': '11/02/2018', 'ocorrencia_hora': '13:30:00', 'investigacao_aeronave_liberada': 'SIM', 'investigacao_status': 'FINALIZADA', 'divulgacao_relatorio_numero': 'A-024/CENIPA/2018', 'divulgacao_relatorio_publicado': 'SIM', 'divulgacao_dia_publicacao': '2019-03-11', 'total_recomendacoes': 0, 'total_aeronaves_envolvidas': 1, 'ocorrencia_saida_pista': 'NÃO'}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.DataFrame(list_cursor)
df.head()
df.tail()
df.shape
# Out:
# (5167, 23)

# %%
from datetime import date, time, datetime
import locale
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
import pandas as pd
import numpy as np

# %%
df_ocorrencias = pd.DataFrame(list_cursor)
df_ocorrencias.shape
# Out:
# (5167, 23)

# %%
location_filter = ['ocorrencia_cidade', 'ocorrencia_uf', 'ocorrencia_latitude', 'ocorrencia_longitude']
location_filter
df_ocorrencias.info()
df_ocorrencias['ocorrencia_data'] = df_ocorrencias.apply(
    lambda row: datetime.strptime(
        row['ocorrencia_dia'] + ' ' +
        (row['ocorrencia_hora'] if isinstance(row['ocorrencia_hora'], str) else '00:00:00'), '%d/%m/%Y %H:%M:%S'),
    axis=1
)
def clean_float(original: str) -> float:
    if isinstance(original, float):
        return original
    try:
        return locale.atof(original)
    except ValueError:
        return np.NaN
occurencies_in_time = df_ocorrencias.groupby(pd.Grouper(key='ocorrencia_data', axis=0, freq='M')).codigo_ocorrencia.count()
occurencies_in_time
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5167 entries, 0 to 5166
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   _id                             5167 non-null   object
#  1   codigo_ocorrencia               5167 non-null   int64
#  2   codigo_ocorrencia1              5167 non-null   int64
#  3   codigo_ocorrencia2              5167 non-null   int64
#  4   codigo_ocorrencia3              5167 non-null   int64
#  5   codigo_ocorrencia4              5167 non-null   int64
#  6   ocorrencia_classificacao        5167 non-null   object
#  7   ocorrencia_latitude             4192 non-null   object
#  8   ocorrencia_longitude            4192 non-null   object
#  9   ocorrencia_cidade               5167 non-null   object
#  10  ocorrencia_uf                   5167 non-null   object
#  11  ocorrencia_pais                 5167 non-null   object
#  12  ocorrencia_aerodromo            5167 non-null   object
#  13  ocorrencia_dia                  5167 non-null   object
#  14  ocorrencia_hora                 5166 non-null   object
#  15  investigacao_aeronave_liberada  5001 non-null   object
#  16  investigacao_status             4910 non-null   object
#  17  divulgacao_relatorio_numero     4783 non-null   object
#  18  divulgacao_relatorio_publicado  5167 non-null   object
#  19  divulgacao_dia_publicacao       1351 non-null   object
#  20  total_recomendacoes             5167 non-null   int64
#  21  total_aeronaves_envolvidas      5167 non-null   int64
#  22  ocorrencia_saida_pista          5167 non-null   object
# dtypes: int64(7), object(16)
# memory usage: 928.6+ KB
# ocorrencia_data
# 2012-01-31    44
# 2012-02-29    51
# 2012-03-31    61
# 2012-04-30    44
# 2012-05-31    51
#               ..
# 2021-08-31    40
# 2021-09-30    38
# 2021-10-31    33
# 2021-11-30    42
# 2021-12-31    50
# Freq: M, Name: codigo_ocorrencia, Length: 120, dtype: int64

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.7.0-py2.py3-none-any.whl (28.8 MB)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from plotly) (1.16.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.7.0 tenacity-8.0.1
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -sspec (c:\programdata\anaconda3\lib\site-packages)

# %%
import plotly.io as pio
import plotly.express as px

# %%
px.line(
    occurencies_in_time,
    title='Ocorrências por mês',
    labels={
        'index': 'Data',
        'ocorrencia_data': 'Mês'
    }
)
occurrence_in_time_by_class = (
    df_ocorrencias
    .set_index('ocorrencia_data')
    .groupby([pd.Grouper(freq='M'), 'ocorrencia_classificacao'])
    .codigo_ocorrencia
    .count()
)
df_ocorrencias.ocorrencia_classificacao.value_counts()
occurrence_in_time_by_class
# Out:
# ocorrencia_data  ocorrencia_classificacao
# 2012-01-31       ACIDENTE                    18
#                  INCIDENTE                   18
#                  INCIDENTE GRAVE              8
# 2012-02-29       ACIDENTE                    20
#                  INCIDENTE                   25
#                                              ..
# 2021-11-30       INCIDENTE                   23
#                  INCIDENTE GRAVE              7
# 2021-12-31       ACIDENTE                    18
#                  INCIDENTE                   25
#                  INCIDENTE GRAVE              7
# Name: codigo_ocorrencia, Length: 359, dtype: int64

# %%
px.bar(
    df_ocorrencias.ocorrencia_classificacao.value_counts().iloc[::-1],
    orientation='h',
    title='Classificação de ocorrências',
    labels={
        'index': 'Tipos de ocorrências',
        'value': 'Quantidades',
    }
)
px.line(
    occurrence_in_time_by_class,
    x=occurrence_in_time_by_class.index.get_level_values(0),
    y=occurrence_in_time_by_class.values,
    color=occurrence_in_time_by_class.index.get_level_values(1),
    title='Clasificação de ocorrências por mês',
    labels={
        'x': 'Tipo de ocorrência',
        'y': 'Quantidades',
    }
)
df_ocorrencias['ocorrencia_latitude'] = df_ocorrencias['ocorrencia_latitude'].apply(clean_float)
df_ocorrencias['ocorrencia_longitude'] = df_ocorrencias['ocorrencia_longitude'].apply(clean_float)

# %%
accidents = df_ocorrencias[df_ocorrencias.ocorrencia_classificacao == 'ACIDENTE']
accidents_2020 = accidents[accidents.ocorrencia_data >= datetime(2020,1,1)]
len(accidents_2020[accidents_2020.ocorrencia_latitude.notna()])
# Out:
# 259

# %%
df.head()
# Out:
#                         _id  codigo_ocorrencia  codigo_ocorrencia1  \
# 0  6279df14c1ef959aa00f2df6              52242               52242
# 1  6279df14c1ef959aa00f2df7              45331               45331
# 2  6279df14c1ef959aa00f2df8              45333               45333
# 3  6279df14c1ef959aa00f2df9              45401               45401
# 4  6279df14c1ef959aa00f2dfa              45407               45407
#
#    codigo_ocorrencia2  codigo_ocorrencia3  codigo_ocorrencia4  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#   ocorrencia_classificacao ocorrencia_latitude ocorrencia_longitude  \
# 0                INCIDENTE                 NaN                  NaN
# 1                 ACIDENTE      -23.4355555556       -46.4730555556
# 2                 ACIDENTE                 ***                  ***
# 3                 ACIDENTE                 ***                  ***
# 4                 ACIDENTE                 ***                  ***
#
#   ocorrencia_cidade  ... ocorrencia_dia ocorrencia_hora  \
# 0      PORTO ALEGRE  ...     05/01/2012        20:27:00
# 1         GUARULHOS  ...     06/01/2012        13:44:00
# 2            VIAMÃO  ...     06/01/2012        13:00:00
# 3     SÃO SEBASTIÃO  ...     06/01/2012        17:00:00
# 4          SÃO SEPÉ  ...     06/01/2012        16:30:00
#
#   investigacao_aeronave_liberada investigacao_status  \
# 0                            ***          FINALIZADA
# 1                            SIM          FINALIZADA
# 2                            NaN          FINALIZADA
# 3                            ***                 NaN
# 4                            SIM          FINALIZADA
#
#   divulgacao_relatorio_numero divulgacao_relatorio_publicado  \
# 0                         ***                            NÃO
# 1           A-582/CENIPA/2014                            SIM
# 2           A-070/CENIPA/2013                            SIM
# 3                         NaN                            NÃO
# 4           A-071/CENIPA/2013                            SIM
#
#   divulgacao_dia_publicacao total_recomendacoes total_aeronaves_envolvidas  \
# 0                       NaN                   0                          1
# 1                2016-09-01                   3                          1
# 2                2013-11-27                   0                          1
# 3                       NaN                   0                          1
# 4                2013-11-27                   0                          1
#
#   ocorrencia_saida_pista
# 0                    NÃO
# 1                    NÃO
# 2                    NÃO
# 3                    NÃO
# 4                    NÃO
#
# [5 rows x 23 columns]
